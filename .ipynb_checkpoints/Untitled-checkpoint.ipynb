# %%
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np
import cmocean as cmo

# %%
acces_pr_file = "data/pr_Amon_ACCESS1-3_historical_r1i1p1_200101-200512.nc"

# %%
dset = xr.open_dataset(acces_pr_file)

# %%
clim = dset['pr'].mean('time',keep_attrs=True)
clim
# Out:
# <xarray.DataArray 'pr' (lat: 145, lon: 192)>
# array([[2.542048e-06, 2.542048e-06, 2.542048e-06, ..., 2.541606e-06,
#         2.541606e-06, 2.541606e-06],
#        [2.511442e-06, 2.492513e-06, 2.472960e-06, ..., 2.570118e-06,
#         2.550404e-06, 2.531296e-06],
#        [2.396512e-06, 2.365124e-06, 2.330266e-06, ..., 2.472362e-06,
#         2.455286e-06, 2.427222e-06],
#        ...,
#        [8.877672e-06, 8.903967e-06, 8.938327e-06, ..., 8.819357e-06,
#         8.859161e-06, 8.873179e-06],
#        [8.748589e-06, 8.739819e-06, 8.723918e-06, ..., 8.797057e-06,
#         8.776324e-06, 8.789103e-06],
#        [7.988647e-06, 7.988647e-06, 7.988647e-06, ..., 7.988647e-06,
#         7.988647e-06, 7.988647e-06]], dtype=float32)
# Coordinates:
#   * lat      (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * lon      (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
# Attributes:
#     standard_name:  precipitation_flux
#     long_name:      Precipitation
#     units:          kg m-2 s-1
#     cell_methods:   time: mean

# %%
# convert units to mm/day
clim.data = clim.data * 86400
clim.attrs['units'] = 'mm/day'
clim
# Out:
# <xarray.DataArray 'pr' (lat: 145, lon: 192)>
# array([[0.219633, 0.219633, 0.219633, ..., 0.219595, 0.219595, 0.219595],
#        [0.216989, 0.215353, 0.213664, ..., 0.222058, 0.220355, 0.218704],
#        [0.207059, 0.204347, 0.201335, ..., 0.213612, 0.212137, 0.209712],
#        ...,
#        [0.767031, 0.769303, 0.772271, ..., 0.761992, 0.765432, 0.766643],
#        [0.755878, 0.75512 , 0.753746, ..., 0.760066, 0.758274, 0.759379],
#        [0.690219, 0.690219, 0.690219, ..., 0.690219, 0.690219, 0.690219]])
# Coordinates:
#   * lat      (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * lon      (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
# Attributes:
#     standard_name:  precipitation_flux
#     long_name:      Precipitation
#     units:          mm/day
#     cell_methods:   time: mean

# %%
fig = plt.figure(figsize=[12,5])
ax = fig.add_subplot(111, projection=ccrs.PlateCarree(central_longitude=180))
clim.plot.contourf(ax=ax,
                   levels=np.arange(0, 13.5, 1.5),
                   extend='max',
                   transform=ccrs.PlateCarree(),
                   cbar_kwargs={'label': clim.units},
                   cmap='cmo.haline')
ax.coastlines()
plt.show()

# %%
test
# Out:
# <xarray.Dataset>
# Dimensions:   (bnds: 2, lat: 145, lon: 192, season: 4)
# Coordinates:
#   * lat       (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * lon       (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
#   * season    (season) object 'DJF' 'JJA' 'MAM' 'SON'
# Dimensions without coordinates: bnds
# Data variables:
#     pr        (season, lat, lon) float32 2.3760513e-06 ... 9.998436e-06
#     lat_bnds  (season, lat, bnds) float64 -90.0 -89.38 -89.38 ... 89.38 90.0
#     lon_bnds  (season, lon, bnds) float64 -0.9375 0.9375 0.9375 ... 357.2 359.1
# Attributes:
#     CDI:                    Climate Data Interface version 1.7.1 (http://mpim...
#     CDO:                    Climate Data Operators version 1.7.1 (http://mpim...
#     NCO:                    4.7.0
#     associated_files:       baseURL: http://cmip-pcmdi.llnl.gov/CMIP5/dataLoc...
#     branch_time:            90945.0
#     cmor_version:           2.8.0
#     comment:                at surface; includes both liquid and solid phases...
#     contact:                The ACCESS wiki: http://wiki.csiro.au/confluence/...
#     creation_date:          2012-02-08T06:45:54Z
#     experiment:             historical
#     experiment_id:          historical
#     forcing:                GHG, Oz, SA, Sl, Vl, BC, OC, (GHG = CO2, N2O, CH4...
#     frequency:              mon
#     history:                Tue Sep 18 11:36:11 2018: /anaconda3/envs/ocean/b...
#     initialization_method:  1
#     institute_id:           CSIRO-BOM
#     institution:            CSIRO (Commonwealth Scientific and Industrial Res...
#     model_id:               ACCESS1.3
#     modeling_realm:         atmos
#     parent_experiment:      pre-industrial control
#     parent_experiment_id:   piControl
#     parent_experiment_rip:  r1i1p1
#     physics_version:        1
#     product:                output
#     project_id:             CMIP5
#     realization:            1
#     references:             See http://wiki.csiro.au/confluence/display/ACCES...
#     source:                 ACCESS1-3 2011. Atmosphere: AGCM v1.0 (N96 grid-p...
#     table_id:               Table Amon (27 April 2011) 9c851218e3842df9a62ef3...
#     title:                  ACCESS1-3 model output prepared for CMIP5 historical
#     tracking_id:            26bfc8da-78ff-4b10-9e13-24492c09bb59
#     version_number:         v20120413
#     Conventions:            CF-1.5

# %%
fig = plt.figure(figsize=[12,5])
ax = fig.add_subplot(111, projection=ccrs.PlateCarree(central_longitude=180))
test['pr'].sel(season='JJA').plot.contourf(ax=ax,
                   levels=np.arange(0, 13.5, 1.5),
                   extend='max',
                   transform=ccrs.PlateCarree(),
                   cbar_kwargs={'label': clim.units},
                   cmap='cmo.haline')
ax.coastlines()
# test['pr'].sel(season='JJA').plot()
ax.set_title(test.attrs['model_id'] + ' precipitation climatology (JJA)')
plt.show()

# %%
# plot season

test = dset.groupby('time.season').mean('time',keep_attrs=True)
test = test * 86400

# create function
def plot_pr_climatology(pr_file,season,gridlines=False):
    """ Plot the precipitation climatology
    
    Args:
        pr_file (str):Precipiation
        season (str): Season (3 letter abbreviation)
    """
    
    dset = xr.open_dataset(pr_file)
    clim = dset['pr'].groupby('time.season').mean('time', keep_attrs=True) 
    clim = convert_pr_units(clim)
    plot_climatology(clim,season)
    
#     fig = plt.figure(figsize=[12,5])
#     ax = fig.add_subplot(111, projection=ccrs.PlateCarree(central_longitude=180))
#     clim.sel(season=season).plot.contourf(ax=ax,
#                        levels=np.arange(0, 13.5, 1.5),
#                        extend='max',
#                        transform=ccrs.PlateCarree(),
#                        cbar_kwargs={'label': clim.units},
#                        cmap='cmo.haline')
#     ax.coastlines()
#     if gridlines:
#         plt.gca().gridlines()
#     ax.set_title(dset.attrs['model_id'] + ' precipitation climatology (' + season + ')')
#     plt.show()

# %%
plot_pr_climatology(acces_pr_file,'DJF',gridlines=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-86bdd46584c6> in <module>
# ----> 1 plot_pr_climatology(acces_pr_file,'DJF',gridlines=False)
#
# <ipython-input-50-fe253811dc76> in plot_pr_climatology(pr_file, season, gridlines)
#      16     clim = dset['pr'].groupby('time.season').mean('time', keep_attrs=True)
#      17     clim = convert_pr_units(clim)
# ---> 18     plot_climatology(clim,season)
#      19
#      20 #     fig = plt.figure(figsize=[12,5])
#
# TypeError: plot_climatology() takes 1 positional argument but 2 were given
